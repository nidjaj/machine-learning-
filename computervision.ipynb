# %% [markdown]
# <a href="https://colab.research.google.com/github/nidjaj/machine-learning-/blob/master/computervision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
image=cv2.imread("60828040.jpg")

# %%
print(image)
# Out:
# [[[111 126 145]
#   [111 126 145]
#   [112 127 146]
#   ...
#   [184 179 180]
#   [184 179 180]
#   [184 179 180]]
#
#  [[111 126 145]
#   [111 126 145]
#   [112 127 146]
#   ...
#   [184 179 180]
#   [184 179 180]
#   [184 179 180]]
#
#  [[111 126 145]
#   [111 126 145]
#   [112 127 146]
#   ...
#   [184 179 180]
#   [184 179 180]
#   [184 179 180]]
#
#  ...
#
#  [[ 38  72 108]
#   [ 36  70 106]
#   [ 31  67 103]
#   ...
#   [ 79  99 130]
#   [ 78  98 129]
#   [ 78  98 129]]
#
#  [[ 40  72 108]
#   [ 38  70 106]
#   [ 33  67 103]
#   ...
#   [ 78  98 129]
#   [ 77  97 128]
#   [ 77  97 128]]
#
#  [[ 42  71 108]
#   [ 38  70 106]
#   [ 33  67 103]
#   ...
#   [ 77  97 128]
#   [ 76  96 127]
#   [ 76  96 127]]]

# %%
type(image)
# Out:
# numpy.ndarray

# %%
# to display images
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F0E8E5756A0>

# %%
img=cv2.imread('60828040.jpg',0)
# 1 means image in same color  channel --GRB or --RBG
# o means no color channel --GRB or --RBG
cv2_imshow(img)
# -1 maintain image transparency ---
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F0E8E5758D0>

# %%
cv2_imshow(img[130:330,300:470])
# Out:
# <PIL.Image.Image image mode=L size=170x200 at 0x7F0E8E575978>

# %%
# to draw a line in image
img1=cv2.line(image,(0,0),(200,230),(0,0,255),3)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F0E8E575668>

# %%
import sys
data=sys.argv[1]
img1=cv2.imread(data,1)
print(img)
# Out:
# [[130 130 131 ... 180 180 180]
#  [130 130 131 ... 180 180 180]
#  [130 130 131 ... 180 180 180]
#  ...
#  [ 79  77  74 ... 106 105 105]
#  [ 79  77  74 ... 105 104 104]
#  [ 79  77  74 ... 104 103 103]]

# %%
img.shape
# Out:
# (600, 800)

# %%
# height ,weight ,color, channel
# to show the image 

cv2_imshow(img-50)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F0E8E575320>

# %%
cv2_imshow(img+100)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F0E8E575518>

# %%
cv2_imshow(img[0:200,0:600]+100)
# Out:
# <PIL.Image.Image image mode=L size=600x200 at 0x7F0E8E575E10>

# %%
cv2_imshow(img/2)
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x7F0E8E5750F0>

# %%
# saving image
cv2.imwrite('60828040.jpg',img1)
# Out:
# False
